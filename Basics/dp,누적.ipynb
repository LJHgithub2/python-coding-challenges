# %% [markdown]
# ### Climbing Stairs(dp)
# ##### 리트코(https://leetcode.com/problems/climbing-stairs/description/)
#
# #### 1. n 개의 계단을 올라야 목적지에 다다를 수 있고 한번에 1계단 혹은 2계단씩 오를수 있다.
# #### 2. 오를수 있는 방법의개수를 구하자
#
# #### 알고리즘
# ##### 1.
#
# #### 입력 데이터
# ##### n = 4
# ##### m = 4
# ##### [[2, 3], [3, 3]]
# #### 출력 데이터
# ##### 5
